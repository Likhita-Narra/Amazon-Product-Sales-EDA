# %% [markdown]
# ### EDA on Amazon Sales Data
#
# #### Hypothesis:
#
# ##### 1: Sales volume varies significantly across different states in India.
# ##### 2: The categories of clothes ordered exhibit a distinct pattern within certain months of the year.

# %%
# Importing the libraries
import pandas as pd
import missingno as msno

# %%
# Loading the dataset
amazon = pd.read_csv("Datasets/Amazon Sale Report.csv", low_memory=False)
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
#  15  Amount              121180 non-null  float64
#  16  ship-city           128942 non-null  object
#  17  ship-state          128942 non-null  object
#  18  ship-postal-code    128942 non-null  float64
#  19  ship-country        128942 non-null  object
#  20  promotion-ids       79822 non-null   object
#  21  B2B                 128975 non-null  bool
#  22  fulfilled-by        39277 non-null   object
#  23  Unnamed: 22         79925 non-null   object
# dtypes: bool(1), float64(2), int64(2), object(19)
# memory usage: 22.8+ MB

# %%
amazon = amazon.drop(['index'], axis=1)

# %% [markdown]
# The matrix depicts the pattern of missigness in the dataset

# %%
# Visualize missing values as a matrix
msno.matrix(amazon)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-2fd326429587> in <module>
#       1 # Visualize missing values as a matrix
# ----> 2 msno.matrix(amazon)
#
# ~\anaconda3\lib\site-packages\missingno\missingno.py in matrix(df, filter, n, p, sort, figsize, width_ratios, color, fontsize, labels, label_rotation, sparkline, freq, ax)
#      84     if labels or (labels is None and len(df.columns) <= 50):
#      85         ha = 'left'
# ---> 86         ax0.set_xticks(list(range(0, width)))
#      87         ax0.set_xticklabels(list(df.columns), rotation=label_rotation, ha=ha, fontsize=fontsize)
#      88     else:
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      61
#      62         def wrapper(self, *args, **kwargs):
# ---> 63             return get_method(self)(*args, **kwargs)
#      64
#      65         wrapper.__module__ = owner.__module__
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in set_ticks(self, ticks, minor)
#    1819         else:
#    1820             self.set_major_locator(mticker.FixedLocator(ticks))
# -> 1821             return self.get_major_ticks(len(ticks))
#    1822
#    1823     def _get_tick_boxes_siblings(self, xdir, renderer):
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1380         while len(self.majorTicks) < numticks:
#    1381             # Update the new tick label properties from the old.
# -> 1382             tick = self._get_tick(major=True)
#    1383             self.majorTicks.append(tick)
#    1384             tick.gridline.set_visible(self._gridOnMajor)
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    2011         else:
#    2012             tick_kw = self._minor_tick_kw
# -> 2013         return XTick(self.axes, 0, major=major, **tick_kw)
#    2014
#    2015     def set_label_position(self, position):
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in __init__(self, *args, **kwargs)
#     415
#     416     def __init__(self, *args, **kwargs):
# --> 417         super().__init__(*args, **kwargs)
#     418         # x in data coords, y in axes coords
#     419         self.tick1line.set(
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     157             markeredgecolor=color, markersize=size, markeredgewidth=width,
#     158         )
# --> 159         self.gridline = mlines.Line2D(
#     160             [], [],
#     161             color=grid_color, alpha=grid_alpha, visible=gridOn,
#
# TypeError: type object got multiple values for keyword argument 'visible'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in _fetch_figure_metadata(fig)
#     178     if _is_transparent(fig.get_facecolor()):
#     179         # the background is transparent
# --> 180         ticksLight = _is_light([label.get_color()
#     181                                 for axes in fig.axes
#     182                                 for axis in (axes.xaxis, axes.yaxis)
#
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in <listcomp>(.0)
#     181                                 for axes in fig.axes
#     182                                 for axis in (axes.xaxis, axes.yaxis)
# --> 183                                 for label in axis.get_ticklabels()])
#     184         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     185             # there are one or more tick labels, all with the same lightness
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in get_ticklabels(self, minor, which)
#    1253         if minor:
#    1254             return self.get_minorticklabels()
# -> 1255         return self.get_majorticklabels()
#    1256
#    1257     def get_majorticklines(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in get_majorticklabels(self)
#    1205     def get_majorticklabels(self):
#    1206         """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1207         ticks = self.get_major_ticks()
#    1208         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1209         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1380         while len(self.majorTicks) < numticks:
#    1381             # Update the new tick label properties from the old.
# -> 1382             tick = self._get_tick(major=True)
#    1383             self.majorTicks.append(tick)
#    1384             tick.gridline.set_visible(self._gridOnMajor)
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    2011         else:
#    2012             tick_kw = self._minor_tick_kw
# -> 2013         return XTick(self.axes, 0, major=major, **tick_kw)
#    2014
#    2015     def set_label_position(self, position):
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in __init__(self, *args, **kwargs)
#     415
#     416     def __init__(self, *args, **kwargs):
# --> 417         super().__init__(*args, **kwargs)
#     418         # x in data coords, y in axes coords
#     419         self.tick1line.set(
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     157             markeredgecolor=color, markersize=size, markeredgewidth=width,
#     158         )
# --> 159         self.gridline = mlines.Line2D(
#     160             [], [],
#     161             color=grid_color, alpha=grid_alpha, visible=gridOn,
#
# TypeError: type object got multiple values for keyword argument 'visible'

# %% [markdown]
# The bar chart depicts the number of missing values in each column of the dataset
#
#  * The pattern of missigness in the 'currency' and 'amount' columns is similar

# %%
msno.bar(amazon)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above bar chart, we can observe that maximum number of missing values exist in the 'fulfilled-by' column

# %%
amazon.apply(pd.unique)
# Out:
# Order ID              [405-8078784-5731545, 171-9198151-1101146, 404...
# Date                  [04-30-22, 04-29-22, 04-28-22, 04-27-22, 04-26...
# Status                [Cancelled, Shipped - Delivered to Buyer, Ship...
# Fulfilment                                           [Merchant, Amazon]
# Sales Channel                                   [Amazon.in, Non-Amazon]
# ship-service-level                                [Standard, Expedited]
# Style                 [SET389, JNE3781, JNE3371, J0341, JNE3671, SET...
# SKU                   [SET389-KR-NP-S, JNE3781-KR-XXXL, JNE3371-KR-X...
# Category              [Set, kurta, Western Dress, Top, Ethnic Dress,...
# Size                   [S, 3XL, XL, L, XXL, XS, 6XL, M, 4XL, 5XL, Free]
# ASIN                  [B09KXVBD7Z, B09K3WFS32, B07WV4JV4D, B099NRCT7...
# Courier Status                     [nan, Shipped, Cancelled, Unshipped]
# Qty                                    [0, 1, 2, 15, 3, 9, 13, 5, 4, 8]
# currency                                                     [INR, nan]
# Amount                [647.62, 406.0, 329.0, 753.33, 574.0, 824.0, 6...
# ship-city             [MUMBAI, BENGALURU, NAVI MUMBAI, PUDUCHERRY, C...
# ship-state            [MAHARASHTRA, KARNATAKA, PUDUCHERRY, TAMIL NAD...
# ship-postal-code      [400081.0, 560085.0, 410210.0, 605008.0, 60007...
# ship-country                                                  [IN, nan]
# promotion-ids         [nan, Amazon PLCC Free-Financing Universal Mer...
# B2B                                                       [False, True]
# fulfilled-by                                           [Easy Ship, nan]
# Unnamed: 22                                                [nan, False]
# dtype: object

# %%
amazon.drop(columns = ['Unnamed: 22', 'fulfilled-by', 'currency', 'Sales Channel '], inplace=True)

# %%
duplicates = len(amazon) - len(amazon.drop_duplicates(['Order ID', 'ASIN']))
amazon.drop_duplicates(['Order ID', 'ASIN'], inplace=True, ignore_index=True)
print(f"{duplicates} duplicates have been removed from the dataset")
# Out:
# 7 duplicates have been removed from the dataset

# %%
amazon.head()
# Out:
#               Order ID      Date                        Status Fulfilment  \
# 0  405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2  404-0687676-7273146  04-30-22                       Shipped     Amazon
# 3  403-9615377-8133951  04-30-22                     Cancelled   Merchant
# 4  407-1069790-7240320  04-30-22                       Shipped     Amazon
#
#   ship-service-level    Style              SKU       Category Size  \
# 0           Standard   SET389   SET389-KR-NP-S            Set    S
# 1           Standard  JNE3781  JNE3781-KR-XXXL          kurta  3XL
# 2          Expedited  JNE3371    JNE3371-KR-XL          kurta   XL
# 3           Standard    J0341       J0341-DR-L  Western Dress    L
# 4          Expedited  JNE3671  JNE3671-TU-XXXL            Top  3XL
#
#          ASIN Courier Status  Qty  Amount    ship-city   ship-state  \
# 0  B09KXVBD7Z            NaN    0  647.62       MUMBAI  MAHARASHTRA
# 1  B09K3WFS32        Shipped    1  406.00    BENGALURU    KARNATAKA
# 2  B07WV4JV4D        Shipped    1  329.00  NAVI MUMBAI  MAHARASHTRA
# 3  B099NRCT7B            NaN    0  753.33   PUDUCHERRY   PUDUCHERRY
# 4  B098714BZP        Shipped    1  574.00      CHENNAI   TAMIL NADU
#
#    ship-postal-code ship-country  \
# 0          400081.0           IN
# 1          560085.0           IN
# 2          410210.0           IN
# 3          605008.0           IN
# 4          600073.0           IN
#
#                                        promotion-ids    B2B
# 0                                                NaN  False
# 1  Amazon PLCC Free-Financing Universal Merchant ...  False
# 2       IN Core Free Shipping 2015/04/08 23-48-5-108   True
# 3                                                NaN  False
# 4                                                NaN  False

# %%
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128968 entries, 0 to 128967
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            128968 non-null  object
#  1   Date                128968 non-null  object
#  2   Status              128968 non-null  object
#  3   Fulfilment          128968 non-null  object
#  4   ship-service-level  128968 non-null  object
#  5   Style               128968 non-null  object
#  6   SKU                 128968 non-null  object
#  7   Category            128968 non-null  object
#  8   Size                128968 non-null  object
#  9   ASIN                128968 non-null  object
#  10  Courier Status      122096 non-null  object
#  11  Qty                 128968 non-null  int64
#  12  Amount              121176 non-null  float64
#  13  ship-city           128935 non-null  object
#  14  ship-state          128935 non-null  object
#  15  ship-postal-code    128935 non-null  float64
#  16  ship-country        128935 non-null  object
#  17  promotion-ids       79818 non-null   object
#  18  B2B                 128968 non-null  bool
# dtypes: bool(1), float64(2), int64(1), object(15)
# memory usage: 17.8+ MB

# %%
amazon.describe()
# Out:
#                  Qty         Amount  ship-postal-code
# count  128968.000000  121176.000000     128935.000000
# mean        0.904449     648.557109     463965.409873
# std         0.313331     281.210629     191475.232007
# min         0.000000       0.000000     110001.000000
# 25%         1.000000     449.000000     382421.000000
# 50%         1.000000     605.000000     500033.000000
# 75%         1.000000     788.000000     600024.000000
# max        15.000000    5584.000000     989898.000000

# %%
amazon[amazon.isnull().any(axis = 1)]
# Out:
#                    Order ID      Date     Status Fulfilment  \
# 0       405-8078784-5731545  04-30-22  Cancelled   Merchant
# 3       403-9615377-8133951  04-30-22  Cancelled   Merchant
# 4       407-1069790-7240320  04-30-22    Shipped     Amazon
# 8       407-5443024-5233168  04-30-22  Cancelled     Amazon
# 9       402-4393761-0311520  04-30-22    Shipped     Amazon
# ...                     ...       ...        ...        ...
# 128959  406-9812666-2474761  05-31-22    Shipped     Amazon
# 128960  404-5182288-1653947  05-31-22  Cancelled     Amazon
# 128962  404-3802633-7250760  05-31-22  Cancelled     Amazon
# 128963  406-6001380-7673107  05-31-22    Shipped     Amazon
# 128965  407-9547469-3152358  05-31-22    Shipped     Amazon
#
#        ship-service-level    Style                  SKU       Category Size  \
# 0                Standard   SET389       SET389-KR-NP-S            Set    S
# 3                Standard    J0341           J0341-DR-L  Western Dress    L
# 4               Expedited  JNE3671      JNE3671-TU-XXXL            Top  3XL
# 8               Expedited   SET200  SET200-KR-NP-A-XXXL            Set  3XL
# 9               Expedited  JNE3461       JNE3461-KR-XXL          kurta  XXL
# ...                   ...      ...                  ...            ...  ...
# 128959          Expedited   SET224      SET224-KR-NP-XS            Set   XS
# 128960          Expedited  JNE3638        JNE3638-KR-XS          kurta   XS
# 128962          Expedited   SET044       SET044-KR-NP-M            Set    M
# 128963          Expedited  JNE3697        JNE3697-KR-XL          kurta   XL
# 128965          Expedited    J0157         J0157-DR-XXL  Western Dress  XXL
#
#               ASIN Courier Status  Qty   Amount       ship-city   ship-state  \
# 0       B09KXVBD7Z            NaN    0   647.62          MUMBAI  MAHARASHTRA
# 3       B099NRCT7B            NaN    0   753.33      PUDUCHERRY   PUDUCHERRY
# 4       B098714BZP        Shipped    1   574.00         CHENNAI   TAMIL NADU
# 8       B08L91ZZXN      Cancelled    0      NaN       HYDERABAD    TELANGANA
# 9       B08B3XF5MH        Shipped    1   363.00         Chennai   TAMIL NADU
# ...            ...            ...  ...      ...             ...          ...
# 128959  B08MXDBRK1        Shipped    1  1132.00  CHENNAI 600042   TAMIL NADU
# 128960  B09814Q3QH      Cancelled    0      NaN         Kolkata  WEST BENGAL
# 128962  B07Q2RTSFB      Unshipped    1   612.00          MUMBAI  MAHARASHTRA
# 128963  B098112V2V        Shipped    1   517.00       HYDERABAD    TELANGANA
# 128965  B0982YZ51B        Shipped    1   690.00       HYDERABAD    TELANGANA
#
#         ship-postal-code ship-country  \
# 0               400081.0           IN
# 3               605008.0           IN
# 4               600073.0           IN
# 8               500008.0           IN
# 9               600041.0           IN
# ...                  ...          ...
# 128959          600042.0           IN
# 128960          700040.0           IN
# 128962          400017.0           IN
# 128963          500013.0           IN
# 128965          500049.0           IN
#
#                                        promotion-ids    B2B
# 0                                                NaN  False
# 3                                                NaN  False
# 4                                                NaN  False
# 8       IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 9                                                NaN  False
# ...                                              ...    ...
# 128959                                           NaN  False
# 128960                                           NaN  False
# 128962                                           NaN  False
# 128963                                           NaN  False
# 128965                                           NaN  False
#
# [49514 rows x 19 columns]

# %%
amazon[amazon['promotion-ids'].isnull()]
# Out:
#                    Order ID      Date     Status Fulfilment  \
# 0       405-8078784-5731545  04-30-22  Cancelled   Merchant
# 3       403-9615377-8133951  04-30-22  Cancelled   Merchant
# 4       407-1069790-7240320  04-30-22    Shipped     Amazon
# 9       402-4393761-0311520  04-30-22    Shipped     Amazon
# 10      407-5633625-6970741  04-30-22    Shipped     Amazon
# ...                     ...       ...        ...        ...
# 128959  406-9812666-2474761  05-31-22    Shipped     Amazon
# 128960  404-5182288-1653947  05-31-22  Cancelled     Amazon
# 128962  404-3802633-7250760  05-31-22  Cancelled     Amazon
# 128963  406-6001380-7673107  05-31-22    Shipped     Amazon
# 128965  407-9547469-3152358  05-31-22    Shipped     Amazon
#
#        ship-service-level    Style              SKU       Category Size  \
# 0                Standard   SET389   SET389-KR-NP-S            Set    S
# 3                Standard    J0341       J0341-DR-L  Western Dress    L
# 4               Expedited  JNE3671  JNE3671-TU-XXXL            Top  3XL
# 9               Expedited  JNE3461   JNE3461-KR-XXL          kurta  XXL
# 10              Expedited  JNE3160   JNE3160-KR-G-S          kurta    S
# ...                   ...      ...              ...            ...  ...
# 128959          Expedited   SET224  SET224-KR-NP-XS            Set   XS
# 128960          Expedited  JNE3638    JNE3638-KR-XS          kurta   XS
# 128962          Expedited   SET044   SET044-KR-NP-M            Set    M
# 128963          Expedited  JNE3697    JNE3697-KR-XL          kurta   XL
# 128965          Expedited    J0157     J0157-DR-XXL  Western Dress  XXL
#
#               ASIN Courier Status  Qty   Amount       ship-city   ship-state  \
# 0       B09KXVBD7Z            NaN    0   647.62          MUMBAI  MAHARASHTRA
# 3       B099NRCT7B            NaN    0   753.33      PUDUCHERRY   PUDUCHERRY
# 4       B098714BZP        Shipped    1   574.00         CHENNAI   TAMIL NADU
# 9       B08B3XF5MH        Shipped    1   363.00         Chennai   TAMIL NADU
# 10      B07K3YQLF1        Shipped    1   685.00         CHENNAI   TAMIL NADU
# ...            ...            ...  ...      ...             ...          ...
# 128959  B08MXDBRK1        Shipped    1  1132.00  CHENNAI 600042   TAMIL NADU
# 128960  B09814Q3QH      Cancelled    0      NaN         Kolkata  WEST BENGAL
# 128962  B07Q2RTSFB      Unshipped    1   612.00          MUMBAI  MAHARASHTRA
# 128963  B098112V2V        Shipped    1   517.00       HYDERABAD    TELANGANA
# 128965  B0982YZ51B        Shipped    1   690.00       HYDERABAD    TELANGANA
#
#         ship-postal-code ship-country promotion-ids    B2B
# 0               400081.0           IN           NaN  False
# 3               605008.0           IN           NaN  False
# 4               600073.0           IN           NaN  False
# 9               600041.0           IN           NaN  False
# 10              600073.0           IN           NaN  False
# ...                  ...          ...           ...    ...
# 128959          600042.0           IN           NaN  False
# 128960          700040.0           IN           NaN  False
# 128962          400017.0           IN           NaN  False
# 128963          500013.0           IN           NaN  False
# 128965          500049.0           IN           NaN  False
#
# [49150 rows x 19 columns]

# %%
amazon['promotion-ids'].fillna('no promotion', inplace=True)

# %%
amazon['Courier Status'].fillna('unknown', inplace = True)

# %%
amazon[amazon['Amount'].isnull()]
# Out:
#                    Order ID      Date     Status Fulfilment  \
# 8       407-5443024-5233168  04-30-22  Cancelled     Amazon
# 29      404-5933402-8801952  04-30-22  Cancelled   Merchant
# 65      171-4137548-0481151  04-30-22  Cancelled     Amazon
# 84      403-9950518-0349133  04-30-22  Cancelled     Amazon
# 95      405-9112089-3379536  04-30-22  Cancelled     Amazon
# ...                     ...       ...        ...        ...
# 128896  406-3923120-4345139  05-31-22  Cancelled     Amazon
# 128900  403-6757403-6097100  05-31-22  Cancelled     Amazon
# 128901  403-6757403-6097100  05-31-22  Cancelled     Amazon
# 128951  408-9513596-4393945  05-31-22  Cancelled     Amazon
# 128960  404-5182288-1653947  05-31-22  Cancelled     Amazon
#
#        ship-service-level    Style                  SKU Category Size  \
# 8               Expedited   SET200  SET200-KR-NP-A-XXXL      Set  3XL
# 29               Standard  JNE2132  JNE2132-KR-398-XXXL    kurta  3XL
# 65              Expedited  JNE3373       JNE3373-KR-XXL    kurta  XXL
# 84              Expedited  JNE3510         JNE3510-KR-M    kurta    M
# 95              Expedited  JNE3405         JNE3405-KR-L    kurta    L
# ...                   ...      ...                  ...      ...  ...
# 128896          Expedited  JNE3801         JNE3801-KR-M    kurta    M
# 128900          Expedited    NW014     NW014-ST-SR-XXXL      Set  3XL
# 128901          Expedited    NW007     NW007-ST-CP-XXXL      Set  3XL
# 128951          Expedited   SET058       SET058-KR-NP-L      Set    L
# 128960          Expedited  JNE3638        JNE3638-KR-XS    kurta   XS
#
#               ASIN Courier Status  Qty  Amount      ship-city      ship-state  \
# 8       B08L91ZZXN      Cancelled    0     NaN      HYDERABAD       TELANGANA
# 29      B07JG3CND8        unknown    0     NaN       GUWAHATI           ASSAM
# 65      B082W8RWN1      Cancelled    0     NaN          Dahod         Gujarat
# 84      B08WPR5MCB      Cancelled    0     NaN      HYDERABAD       TELANGANA
# 95      B081WSCKPQ      Cancelled    0     NaN           PUNE     MAHARASHTRA
# ...            ...            ...  ...     ...            ...             ...
# 128896  B09SDZ4FH9      Cancelled    0     NaN      ANANTAPUR  ANDHRA PRADESH
# 128900  B0928ZT74Y      Cancelled    0     NaN  GREATER NOIDA   UTTAR PRADESH
# 128901  B0928YCMQP      Cancelled    0     NaN  GREATER NOIDA   UTTAR PRADESH
# 128951  B07R487XRD      Cancelled    0     NaN      Bengaluru       KARNATAKA
# 128960  B09814Q3QH      Cancelled    0     NaN        Kolkata     WEST BENGAL
#
#         ship-postal-code ship-country  \
# 8               500008.0           IN
# 29              781003.0           IN
# 65              389151.0           IN
# 84              500072.0           IN
# 95              411046.0           IN
# ...                  ...          ...
# 128896          515001.0           IN
# 128900          201306.0           IN
# 128901          201306.0           IN
# 128951          560037.0           IN
# 128960          700040.0           IN
#
#                                        promotion-ids    B2B
# 8       IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 29                                      no promotion  False
# 65                                      no promotion  False
# 84                                      no promotion  False
# 95                                      no promotion  False
# ...                                              ...    ...
# 128896                                  no promotion  False
# 128900                                  no promotion  False
# 128901                                  no promotion  False
# 128951                                  no promotion  False
# 128960                                  no promotion  False
#
# [7792 rows x 19 columns]

# %%
amazon['Amount'].fillna(0, inplace = True)

# %%
msno.matrix(amazon)
# Out:
# <AxesSubplot:>

# %%
amazon[amazon['ship-city'].isnull()]
# Out:
#                    Order ID      Date                        Status  \
# 1871    404-0566904-4825137  04-29-22                       Shipped
# 1872    404-0566904-4825137  04-29-22                       Shipped
# 8752    406-4003386-8768363  04-25-22                       Shipped
# 11215   402-0107720-7057168  04-23-22                       Shipped
# 13252   407-4532637-8415521  04-22-22                     Cancelled
# 15688   404-9229894-8608305  04-21-22                       Shipped
# 16787   402-4919636-4333150  04-20-22  Shipped - Delivered to Buyer
# 18351   405-4927647-8064368  04-19-22                       Shipped
# 22930   402-8628677-0457954  04-16-22  Shipped - Returned to Seller
# 24986   406-4079063-8291520  04-15-22                     Cancelled
# 30379   404-7506843-7913132  04-12-22  Shipped - Delivered to Buyer
# 37962   407-3064376-9158743  04-08-22                     Cancelled
# 37963   407-3064376-9158743  04-08-22                     Cancelled
# 60983   171-3257610-9237139  05-22-22  Shipped - Delivered to Buyer
# 63037   402-1049475-3611523  05-20-22                       Shipped
# 73672   405-1356730-8598722  05-11-22  Shipped - Delivered to Buyer
# 73743   407-4664354-2179554  05-11-22                       Shipped
# 73768   406-7680604-5439529  05-11-22                       Shipped
# 73769   406-7680604-5439529  05-11-22                       Shipped
# 73908   405-3420451-5230744  05-11-22                     Cancelled
# 80007   171-4552355-0255565  05-07-22  Shipped - Returned to Seller
# 80088   403-2857451-7335536  05-07-22                       Shipped
# 80451   171-4691098-8489159  05-06-22  Shipped - Delivered to Buyer
# 84004   405-8605864-8021901  05-04-22  Shipped - Returned to Seller
# 84753   402-8651786-0683548  05-04-22                       Shipped
# 104194  403-3190636-2013146  06-18-22  Shipped - Delivered to Buyer
# 106491  402-8673941-7883531  06-16-22                     Cancelled
# 124208  405-0340492-2359532  06-04-22                     Cancelled
# 124350  405-5884153-9925116  06-04-22                       Shipped
# 124351  405-5884153-9925116  06-04-22                       Shipped
# 124352  405-5884153-9925116  06-04-22                       Shipped
# 125378  403-5172380-9787567  06-03-22                       Shipped
# 126613  403-4249038-6582716  06-02-22  Shipped - Delivered to Buyer
#
#        Fulfilment ship-service-level     Style                       SKU  \
# 1871       Amazon          Expedited     J0301                J0301-TP-L
# 1872       Amazon          Expedited   JNE3697              JNE3697-KR-L
# 8752       Amazon          Expedited   JNE3376              JNE3376-KR-M
# 11215      Amazon          Expedited     J0003               J0003-SET-S
# 13252    Merchant           Standard   JNE3405              JNE3405-KR-S
# 15688      Amazon          Expedited   JNE3510              JNE3510-KR-M
# 16787    Merchant           Standard   JNE1233  JNE1233-BLUE-KR-031-XXXL
# 18351      Amazon          Expedited     J0230              J0230-SKD-XS
# 22930    Merchant           Standard     J0003               J0003-SET-S
# 24986      Amazon          Expedited   JNE3567            JNE3567-KR-XXL
# 30379    Merchant           Standard    SET350            SET350-KR-NP-L
# 37962    Merchant           Standard   JNE3567              JNE3567-KR-M
# 37963    Merchant           Standard   JNE3405              JNE3405-KR-S
# 60983    Merchant           Standard   JNE3365       JNE3365-KR-1052-A-L
# 63037      Amazon          Expedited   JNE3739            JNE3739-KR-XXL
# 73672    Merchant           Standard    SET187           SET187-KR-DH-XL
# 73743      Amazon          Expedited    SET374            SET374-KR-NP-M
# 73768      Amazon          Expedited  PJNE3607           PJNE3607-KR-4XL
# 73769      Amazon          Expedited  PJNE3368           PJNE3368-KR-4XL
# 73908      Amazon          Expedited    SET374            SET374-KR-NP-M
# 80007    Merchant           Standard    SET324           SET324-KR-NP-XL
# 80088      Amazon          Expedited   JNE3510              JNE3510-KR-S
# 80451    Merchant           Standard    SET183            SET183-KR-DH-M
# 84004    Merchant           Standard   JNE1951        JNE1951-KR-155-XXL
# 84753      Amazon          Expedited   JNE3690             JNE3690-TU-XL
# 104194   Merchant           Standard     J0351               J0351-SET-S
# 106491     Amazon          Expedited   JNE3734             JNE3734-KR-XL
# 124208     Amazon          Expedited   JNE3465              JNE3465-KR-L
# 124350     Amazon          Expedited   JNE3697              JNE3697-KR-L
# 124351     Amazon          Expedited    SET337            SET337-KR-NP-L
# 124352     Amazon          Expedited    SET154            SET154-KR-NP-L
# 125378     Amazon          Expedited   JNE3366         JNE3366-KR-1053-L
# 126613   Merchant           Standard   JNE3797              JNE3797-KR-M
#
#              Category Size        ASIN Courier Status  Qty  Amount ship-city  \
# 1871              Top    L  B099S6795L        Shipped    1   493.0       NaN
# 1872            kurta    L  B09811Y7WM        Shipped    1   458.0       NaN
# 8752            kurta    M  B082W7HW86        Shipped    1   432.0       NaN
# 11215             Set    S  B0894X27FC        Shipped    1   654.0       NaN
# 13252           kurta    S  B081WX4G4Q        unknown    0   380.0       NaN
# 15688           kurta    M  B08WPR5MCB        Shipped    1   442.0       NaN
# 16787           kurta  3XL  B07GPGP46N        Shipped    1   376.0       NaN
# 18351             Set   XS  B08XNHXSFZ        Shipped    1  1112.0       NaN
# 22930             Set    S  B0894X27FC        Shipped    1   654.0       NaN
# 24986           kurta  XXL  B08KRYCC8J      Unshipped    1   399.0       NaN
# 30379             Set    L  B09RKDXRZK        Shipped    1  1299.0       NaN
# 37962           kurta    M  B08KRXV1QR        unknown    0   380.0       NaN
# 37963           kurta    S  B081WX4G4Q        unknown    0   380.0       NaN
# 60983           kurta    L  B07WP5GQKV        Shipped    1   376.0       NaN
# 63037           kurta  XXL  B099NK7Y5P        Shipped    1   459.0       NaN
# 73672             Set   XL  B08B415N6S        Shipped    1   699.0       NaN
# 73743             Set    M  B09NDKJKPN        Shipped    1   666.0       NaN
# 73768           kurta  4XL  B09PY7YGTC        Shipped    1   869.0       NaN
# 73769           kurta  4XL  B09PY691XK        Shipped    1   869.0       NaN
# 73908             Set    M  B09NDKJKPN      Cancelled    0     0.0       NaN
# 80007             Set   XL  B09NQ4QS13        Shipped    1   607.0       NaN
# 80088           kurta    S  B08WPTJBBD        Shipped    1   467.0       NaN
# 80451             Set    M  B08B3Z2YY3        Shipped    1   759.0       NaN
# 84004           kurta  XXL  B07141LX6Q        Shipped    1   368.0       NaN
# 84753             Top   XL  B094FKN153        Shipped    1   487.0       NaN
# 104194            Set    S  B09CT88XNF        Shipped    1   792.0       NaN
# 106491          kurta   XL  B09RKDBVR6      Cancelled    0     0.0       NaN
# 124208          kurta    L  B08BFLKNGJ      Unshipped    1   491.0       NaN
# 124350          kurta    L  B09811Y7WM        Shipped    1   486.0       NaN
# 124351            Set    L  B09KXY99M3        Shipped    1   874.0       NaN
# 124352            Set    L  B082PXXBXM        Shipped    1   832.0       NaN
# 125378          kurta    L  B07T65WM8Q        Shipped    1   376.0       NaN
# 126613  Western Dress    M  B09SDY8DCT        Shipped    1   735.0       NaN
#
#        ship-state  ship-postal-code ship-country  \
# 1871          NaN               NaN          NaN
# 1872          NaN               NaN          NaN
# 8752          NaN               NaN          NaN
# 11215         NaN               NaN          NaN
# 13252         NaN               NaN          NaN
# 15688         NaN               NaN          NaN
# 16787         NaN               NaN          NaN
# 18351         NaN               NaN          NaN
# 22930         NaN               NaN          NaN
# 24986         NaN               NaN          NaN
# 30379         NaN               NaN          NaN
# 37962         NaN               NaN          NaN
# 37963         NaN               NaN          NaN
# 60983         NaN               NaN          NaN
# 63037         NaN               NaN          NaN
# 73672         NaN               NaN          NaN
# 73743         NaN               NaN          NaN
# 73768         NaN               NaN          NaN
# 73769         NaN               NaN          NaN
# 73908         NaN               NaN          NaN
# 80007         NaN               NaN          NaN
# 80088         NaN               NaN          NaN
# 80451         NaN               NaN          NaN
# 84004         NaN               NaN          NaN
# 84753         NaN               NaN          NaN
# 104194        NaN               NaN          NaN
# 106491        NaN               NaN          NaN
# 124208        NaN               NaN          NaN
# 124350        NaN               NaN          NaN
# 124351        NaN               NaN          NaN
# 124352        NaN               NaN          NaN
# 125378        NaN               NaN          NaN
# 126613        NaN               NaN          NaN
#
#                                             promotion-ids    B2B
# 1871         IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 1872         IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 8752                                         no promotion  False
# 11215        IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 13252                                        no promotion  False
# 15688        IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 16787   Amazon PLCC Free-Financing Universal Merchant ...  False
# 18351        IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 22930   Amazon PLCC Free-Financing Universal Merchant ...  False
# 24986                                        no promotion  False
# 30379   Amazon PLCC Free-Financing Universal Merchant ...  False
# 37962                                        no promotion  False
# 37963                                        no promotion  False
# 60983   Amazon PLCC Free-Financing Universal Merchant ...  False
# 63037        IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 73672   Amazon PLCC Free-Financing Universal Merchant ...  False
# 73743        IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 73768        IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 73769        IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 73908                                        no promotion  False
# 80007   Amazon PLCC Free-Financing Universal Merchant ...  False
# 80088        IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 80451   Amazon PLCC Free-Financing Universal Merchant ...  False
# 84004   Amazon PLCC Free-Financing Universal Merchant ...  False
# 84753                                        no promotion  False
# 104194  Amazon PLCC Free-Financing Universal Merchant ...  False
# 106491       IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 124208                                       no promotion  False
# 124350       IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 124351       IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 124352       IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 125378       IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 126613  Amazon PLCC Free-Financing Universal Merchant ...  False

# %%
amazon['ship-city'].fillna('unknown', inplace = True)
amazon['ship-state'].fillna('unknown', inplace = True)
amazon['ship-postal-code'].fillna('unknown', inplace = True)
amazon['ship-country'].fillna('unknown', inplace = True)

# %%
msno.matrix(amazon)
# Out:
# <AxesSubplot:>

# %%
mapper = {
    'Order ID' : 'orderID',
    'Date' : 'date',
    'Status' : 'shipStatus',
    'Fulfilment' : 'fullfilment', 
    'ship-service-level' : 'serviceLevel', 
    'Style' : 'style', 
    'SKU' : 'sku', 
    'Category' : 'productCategory', 
    'Size' : 'size', 
    'ASIN' : 'asin', 
    'Courier Status' : 'courierShipStatus', 
    'Qty' : 'orderQuantity', 
    'Amount' : 'orderAmount (INR)', 
    'ship-city' : 'city', 
    'ship-state' : 'state',
    'ship-postal-code' : 'zip',
    'ship-country' : 'country', 
    'promotion-ids' : 'promotion',
    'B2B' : 'customerType'
}

amazon.rename(columns = mapper, inplace = True)

# %%
amazon.head()
# Out:
#                orderID      date                    shipStatus fullfilment  \
# 0  405-8078784-5731545  04-30-22                     Cancelled    Merchant
# 1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer    Merchant
# 2  404-0687676-7273146  04-30-22                       Shipped      Amazon
# 3  403-9615377-8133951  04-30-22                     Cancelled    Merchant
# 4  407-1069790-7240320  04-30-22                       Shipped      Amazon
#
#   serviceLevel    style              sku productCategory size        asin  \
# 0     Standard   SET389   SET389-KR-NP-S             Set    S  B09KXVBD7Z
# 1     Standard  JNE3781  JNE3781-KR-XXXL           kurta  3XL  B09K3WFS32
# 2    Expedited  JNE3371    JNE3371-KR-XL           kurta   XL  B07WV4JV4D
# 3     Standard    J0341       J0341-DR-L   Western Dress    L  B099NRCT7B
# 4    Expedited  JNE3671  JNE3671-TU-XXXL             Top  3XL  B098714BZP
#
#   courierShipStatus  orderQuantity  orderAmount (INR)         city  \
# 0           unknown              0             647.62       MUMBAI
# 1           Shipped              1             406.00    BENGALURU
# 2           Shipped              1             329.00  NAVI MUMBAI
# 3           unknown              0             753.33   PUDUCHERRY
# 4           Shipped              1             574.00      CHENNAI
#
#          state       zip country  \
# 0  MAHARASHTRA  400081.0      IN
# 1    KARNATAKA  560085.0      IN
# 2  MAHARASHTRA  410210.0      IN
# 3   PUDUCHERRY  605008.0      IN
# 4   TAMIL NADU  600073.0      IN
#
#                                            promotion  customerType
# 0                                       no promotion         False
# 1  Amazon PLCC Free-Financing Universal Merchant ...         False
# 2       IN Core Free Shipping 2015/04/08 23-48-5-108          True
# 3                                       no promotion         False
# 4                                       no promotion         False

# %%
amazon['customerType'].replace([True, False], ['business', 'consumer'], inplace = True)
amazon.head()
# Out:
#                orderID      date                    shipStatus fullfilment  \
# 0  405-8078784-5731545  04-30-22                     Cancelled    Merchant
# 1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer    Merchant
# 2  404-0687676-7273146  04-30-22                       Shipped      Amazon
# 3  403-9615377-8133951  04-30-22                     Cancelled    Merchant
# 4  407-1069790-7240320  04-30-22                       Shipped      Amazon
#
#   serviceLevel    style              sku productCategory size        asin  \
# 0     Standard   SET389   SET389-KR-NP-S             Set    S  B09KXVBD7Z
# 1     Standard  JNE3781  JNE3781-KR-XXXL           kurta  3XL  B09K3WFS32
# 2    Expedited  JNE3371    JNE3371-KR-XL           kurta   XL  B07WV4JV4D
# 3     Standard    J0341       J0341-DR-L   Western Dress    L  B099NRCT7B
# 4    Expedited  JNE3671  JNE3671-TU-XXXL             Top  3XL  B098714BZP
#
#   courierShipStatus  orderQuantity  orderAmount (INR)         city  \
# 0           unknown              0             647.62       MUMBAI
# 1           Shipped              1             406.00    BENGALURU
# 2           Shipped              1             329.00  NAVI MUMBAI
# 3           unknown              0             753.33   PUDUCHERRY
# 4           Shipped              1             574.00      CHENNAI
#
#          state       zip country  \
# 0  MAHARASHTRA  400081.0      IN
# 1    KARNATAKA  560085.0      IN
# 2  MAHARASHTRA  410210.0      IN
# 3   PUDUCHERRY  605008.0      IN
# 4   TAMIL NADU  600073.0      IN
#
#                                            promotion customerType
# 0                                       no promotion     consumer
# 1  Amazon PLCC Free-Financing Universal Merchant ...     consumer
# 2       IN Core Free Shipping 2015/04/08 23-48-5-108     business
# 3                                       no promotion     consumer
# 4                                       no promotion     consumer

# %%
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128968 entries, 0 to 128967
# Data columns (total 19 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   orderID            128968 non-null  object
#  1   date               128968 non-null  object
#  2   shipStatus         128968 non-null  object
#  3   fullfilment        128968 non-null  object
#  4   serviceLevel       128968 non-null  object
#  5   style              128968 non-null  object
#  6   sku                128968 non-null  object
#  7   productCategory    128968 non-null  object
#  8   size               128968 non-null  object
#  9   asin               128968 non-null  object
#  10  courierShipStatus  128968 non-null  object
#  11  orderQuantity      128968 non-null  int64
#  12  orderAmount (INR)  128968 non-null  float64
#  13  city               128968 non-null  object
#  14  state              128968 non-null  object
#  15  zip                128968 non-null  object
#  16  country            128968 non-null  object
#  17  promotion          128968 non-null  object
#  18  customerType       128968 non-null  object
# dtypes: float64(1), int64(1), object(17)
# memory usage: 18.7+ MB

# %%
amazon['date'] = pd.to_datetime(amazon['date'])
amazon['month'] = amazon['date'].dt.month

# %%
amazon['month'].unique()
# Out:
# array([4, 3, 5, 6], dtype=int64)

# %%
amazon['date'].max()
# Out:
# Timestamp('2022-06-29 00:00:00')

# %%
amazon['date'].min()
# Out:
# Timestamp('2022-03-31 00:00:00')

# %%
months = ['March', 'April', 'May', 'June']
amazon['month'].replace([3, 4, 5, 6], months, inplace = True)

# %%
amazon.set_index('orderID', inplace = True)
amazon
# Out:
#                           date                    shipStatus fullfilment  \
# orderID
# 405-8078784-5731545 2022-04-30                     Cancelled    Merchant
# 171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer    Merchant
# 404-0687676-7273146 2022-04-30                       Shipped      Amazon
# 403-9615377-8133951 2022-04-30                     Cancelled    Merchant
# 407-1069790-7240320 2022-04-30                       Shipped      Amazon
# ...                        ...                           ...         ...
# 406-6001380-7673107 2022-05-31                       Shipped      Amazon
# 402-9551604-7544318 2022-05-31                       Shipped      Amazon
# 407-9547469-3152358 2022-05-31                       Shipped      Amazon
# 402-6184140-0545956 2022-05-31                       Shipped      Amazon
# 408-7436540-8728312 2022-05-31                       Shipped      Amazon
#
#                     serviceLevel    style              sku productCategory  \
# orderID
# 405-8078784-5731545     Standard   SET389   SET389-KR-NP-S             Set
# 171-9198151-1101146     Standard  JNE3781  JNE3781-KR-XXXL           kurta
# 404-0687676-7273146    Expedited  JNE3371    JNE3371-KR-XL           kurta
# 403-9615377-8133951     Standard    J0341       J0341-DR-L   Western Dress
# 407-1069790-7240320    Expedited  JNE3671  JNE3671-TU-XXXL             Top
# ...                          ...      ...              ...             ...
# 406-6001380-7673107    Expedited  JNE3697    JNE3697-KR-XL           kurta
# 402-9551604-7544318    Expedited   SET401   SET401-KR-NP-M             Set
# 407-9547469-3152358    Expedited    J0157     J0157-DR-XXL   Western Dress
# 402-6184140-0545956    Expedited    J0012     J0012-SKD-XS             Set
# 408-7436540-8728312    Expedited    J0003      J0003-SET-S             Set
#
#                     size        asin courierShipStatus  orderQuantity  \
# orderID
# 405-8078784-5731545    S  B09KXVBD7Z           unknown              0
# 171-9198151-1101146  3XL  B09K3WFS32           Shipped              1
# 404-0687676-7273146   XL  B07WV4JV4D           Shipped              1
# 403-9615377-8133951    L  B099NRCT7B           unknown              0
# 407-1069790-7240320  3XL  B098714BZP           Shipped              1
# ...                  ...         ...               ...            ...
# 406-6001380-7673107   XL  B098112V2V           Shipped              1
# 402-9551604-7544318    M  B09VC6KHX8           Shipped              1
# 407-9547469-3152358  XXL  B0982YZ51B           Shipped              1
# 402-6184140-0545956   XS  B0894Y2NJQ           Shipped              1
# 408-7436540-8728312    S  B0894X27FC           Shipped              1
#
#                      orderAmount (INR)         city         state       zip  \
# orderID
# 405-8078784-5731545             647.62       MUMBAI   MAHARASHTRA  400081.0
# 171-9198151-1101146             406.00    BENGALURU     KARNATAKA  560085.0
# 404-0687676-7273146             329.00  NAVI MUMBAI   MAHARASHTRA  410210.0
# 403-9615377-8133951             753.33   PUDUCHERRY    PUDUCHERRY  605008.0
# 407-1069790-7240320             574.00      CHENNAI    TAMIL NADU  600073.0
# ...                                ...          ...           ...       ...
# 406-6001380-7673107             517.00    HYDERABAD     TELANGANA  500013.0
# 402-9551604-7544318             999.00     GURUGRAM       HARYANA  122004.0
# 407-9547469-3152358             690.00    HYDERABAD     TELANGANA  500049.0
# 402-6184140-0545956            1199.00        Halol       Gujarat  389350.0
# 408-7436540-8728312             696.00       Raipur  CHHATTISGARH  492014.0
#
#                     country  \
# orderID
# 405-8078784-5731545      IN
# 171-9198151-1101146      IN
# 404-0687676-7273146      IN
# 403-9615377-8133951      IN
# 407-1069790-7240320      IN
# ...                     ...
# 406-6001380-7673107      IN
# 402-9551604-7544318      IN
# 407-9547469-3152358      IN
# 402-6184140-0545956      IN
# 408-7436540-8728312      IN
#
#                                                              promotion  \
# orderID
# 405-8078784-5731545                                       no promotion
# 171-9198151-1101146  Amazon PLCC Free-Financing Universal Merchant ...
# 404-0687676-7273146       IN Core Free Shipping 2015/04/08 23-48-5-108
# 403-9615377-8133951                                       no promotion
# 407-1069790-7240320                                       no promotion
# ...                                                                ...
# 406-6001380-7673107                                       no promotion
# 402-9551604-7544318       IN Core Free Shipping 2015/04/08 23-48-5-108
# 407-9547469-3152358                                       no promotion
# 402-6184140-0545956       IN Core Free Shipping 2015/04/08 23-48-5-108
# 408-7436540-8728312       IN Core Free Shipping 2015/04/08 23-48-5-108
#
#                     customerType  month
# orderID
# 405-8078784-5731545     consumer  April
# 171-9198151-1101146     consumer  April
# 404-0687676-7273146     business  April
# 403-9615377-8133951     consumer  April
# 407-1069790-7240320     consumer  April
# ...                          ...    ...
# 406-6001380-7673107     consumer    May
# 402-9551604-7544318     consumer    May
# 407-9547469-3152358     consumer    May
# 402-6184140-0545956     consumer    May
# 408-7436540-8728312     consumer    May
#
# [128968 rows x 19 columns]

# %%
amazon.to_csv('Datasets/Final Amazon Dataset.csv', index = False)
